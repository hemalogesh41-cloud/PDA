# %%
# !pip install pandas
# Out:
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !pip install pandas
# Out:
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !conda install pandas -y
# Out:
# 'conda' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (3.0.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: C:\Users\user\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
import pandas as pd 
import numpy as np

s = pd.Series() 
print("Pandas Series: ", s) 
data = np.array(['g', 'e', 'e', 'k', 's']) 
  
s = pd.Series(data) 
print("Pandas Series:\n", s)
# Out:
# Pandas Series:  Series([], dtype: object)
# Pandas Series:
#  0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: str

# %%
import pandas as pd 
   
df = pd.DataFrame() 
print(df)
lst = ['Geeks', 'For', 'Geeks', 'is', 'portal', 'for', 'Geeks'] 
  
df = pd.DataFrame(lst) 
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#         0
# 0   Geeks
# 1     For
# 2   Geeks
# 3      is
# 4  portal
# 5     for
# 6   Geeks

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\user\Desktop\PDA\data.csv")
print(df.head())
# Out:
#          Date  Temperature
# 0  2010-01-01    27.483571
# 1  2010-01-02    24.308678
# 2  2010-01-03    28.238443
# 3  2010-01-04    32.615149
# 4  2010-01-05    23.829233

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\user\Desktop\PDA\data.csv")
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         8000 non-null   str
#  1   Temperature  8000 non-null   float64
# dtypes: float64(1), str(1)
# memory usage: 125.1 KB
# None

# %%
df = df.fillna(0)
print(df.isnull().sum())
# Out:
# Date           0
# Temperature    0
# dtype: int64

# %%
import pandas as pd 
s = pd.Series([10, 20, 30, 40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd
s = pd.Series([85, 90, 78], index=["A", "B", "C"])
print(s)
# Out:
# A    85
# B    90
# C    78
# dtype: int64

# %%
s = pd.Series([10, 20, 30], index=["A", "B", "C"])
s.mean(), s.max(), s.min()
# Out:
# (np.float64(20.0), np.int64(30), np.int64(10))

# %%
s = pd.Series([10, 20, 30], index=["A", "B", "C"])
data = { 
"Name": ["Amit", "Riya", "Karan"], 
"Marks": [85, 90, 78] 
} 
df = pd.DataFrame(data)

print(df["Name"])
print(df["Marks"])
print(df.iloc[0])
print(df)
# Out:
# 0     Amit
# 1     Riya
# 2    Karan
# Name: Name, dtype: str
# 0    85
# 1    90
# 2    78
# Name: Marks, dtype: int64
# Name     Amit
# Marks      85
# Name: 0, dtype: object
#     Name  Marks
# 0   Amit     85
# 1   Riya     90
# 2  Karan     78

# %%
s = pd.Series([10, 20, 30], index=["A", "B", "C"])

df["Name"]
print(df["Name"])
# Out:
# 0     Amit
# 1     Riya
# 2    Karan
# Name: Name, dtype: str

# %%
s = pd.Series([10, 20, 30], index=["A", "B", "C"])

df.loc[0] 
df.iloc[1]

print(df.loc[0])
# Out:
# Name     Amit
# Marks      85
# Name: 0, dtype: object

# %%
s = pd.Series([10, 20, 30], index=["A", "B", "C"])

df["Grade"] = ["A", "A+", "B"]
print(df["Grade"])
# Out:
# 0     A
# 1    A+
# 2     B
# Name: Grade, dtype: str

# %%
s = pd.Series([10, 20, 30], index=["A", "B", "C"])

df.drop("Grade", axis=1)
print(df)
# Out:
#     Name  Marks Grade
# 0   Amit     85     A
# 1   Riya     90    A+
# 2  Karan     78     B

# %%
s = pd.Series([10, 20, 30], index=["A", "B", "C"])

df[df["Marks"] > 80]
print(df)
# Out:
#     Name  Marks Grade
# 0   Amit     85     A
# 1   Riya     90    A+
# 2  Karan     78     B

# %%
df = pd.DataFrame({"values": [10, 20, 30]}, index=["A", "B", "C"])
print(df)
print(df.describe())
# Out:
#    values
# A      10
# B      20
# C      30
#        values
# count     3.0
# mean     20.0
# std      10.0
# min      10.0
# 25%      15.0
# 50%      20.0
# 75%      25.0
# max      30.0
